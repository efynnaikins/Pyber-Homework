# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "city_data.csv"
ride_data_to_load = "ride_data.csv"

# Read the City and Ride Data
city=pd.read_csv(city_data_to_load)
rides=pd.read_csv(ride_data_to_load)
city.head(),rides.head()
#city=cit.drop_duplicates('city', keep = 'first')
# Combine the data into a single dataset
pyber_data=pd.merge(rides,city,how="left",on='city')


# Display the data table for preview
pyber_data.head(10)
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
# 5        South Latoya  2018-03-11 12:26:48   9.52  1994999424437
# 6       New Paulville  2018-02-27 11:17:56  43.25   793208410091
# 7        Simpsonburgh  2018-04-26 00:43:24  35.98   111953927754
# 8     South Karenland  2018-01-08 03:28:48  35.09  7995623208694
# 9       North Jasmine  2018-03-09 06:26:29  42.81  5327642267789
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban
# 5            10  Urban
# 6            44  Urban
# 7            21  Urban
# 8             4  Urban
# 9            33  Urban

# %%
#groupy by city
city_group=pyber_data.groupby(["city"])
#City Type

city_type=pyber_data.groupby(["city"])["type"].unique()
city_types=pd.DataFrame({"Type of City":city_type})
#Driver Count

city_drivers=city_group["driver_count"].count()
# ride counts
city_trips=city_group['ride_id'].count()
#Average Fare
city_Avg_fare=city_group['fare'].mean()

# %%
Pyber_Sum_data = pd.DataFrame({
    "Rides Count": city_trips,
    "Average Fare": city_Avg_fare,
    "Driver Count": city_drivers,
    "City Type":city_type
})

# %%
Pyber_Sum_data.head()
# Out:
#                Average Fare   City Type  Driver Count  Rides Count
# city
# Amandaburgh       24.641667     [Urban]            18           18
# Barajasview       25.332273     [Urban]            22           22
# Barronchester     36.422500  [Suburban]            16           16
# Bethanyland       32.956111  [Suburban]            18           18
# Bradshawfurt      40.064000     [Rural]            10           10

# %%
rural=Pyber_Sum_data[Pyber_Sum_data['City Type']=='Rural']
suburban=Pyber_Sum_data[Pyber_Sum_data['City Type']=='Suburban']
urban=Pyber_Sum_data[Pyber_Sum_data['City Type']=='Urban']

# %%
plt.suptitle('Pyber Ride Sharing Data(2016)')
plt.scatter(rural['Rides Count'],rural['Average Fare'],s=rural['Driver Count']*5,alpha=0.85,c='gold',edgecolor = 'black', label = 'Rural')
plt.scatter(suburban['Rides Count'],suburban['Average Fare'],s=suburban['Driver Count']*10,alpha=0.85,c='skyblue',edgecolor = 'black', label = 'Suburban')
plt.scatter(urban['Rides Count'],urban['Average Fare'],s=urban['Driver Count']*20,alpha=0.85,c='orange',edgecolor = 'black', label = 'Urban')
plt.legend()
plt.show()

# %%
# pyber_city_count=pyber_data.groupby(["city"])['ride_id'].count()
# pyber_city_price=pyber_data.groupby(["type"])['fare'].sum()
# pyber_city_avg=pyber_city_price/pyber_city_count
# pyber_city_type=pyber_data.groupby(["type"])['driver_count'].sum()
# pyber_city_type.describe()
# # print(gender_trips)
# # gender_trips=gender_trips.drop(gender_trips.index[3])
# # chart=gender_trips.plot(kind='bar',title="Bike Trips By Gender")
# # plt.show()

# pyber_city_avg,pyber_city_count

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Calculate Type Percents
pyber_city_price=pyber_data.groupby(["type"])['fare'].sum()
pyber_city_price=pyber_city_price.sort_values(ascending=False)
# Build Pie Chart
type_city = pyber_city_price.index

# %%
colors=["#FA8072","skyblue","gold"]
explode=[0.1,0,0]
plt.pie(pyber_city_price,explode=explode,labels=type_city,colors=colors,autopct="%1.1f%%",shadow=True,startangle=270)
plt.title('% of Total Fares by City Type')
plt.show()
plt.savefig("Total Fare Price By City.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Type Percents
pyber_city_rides=pyber_data.groupby(["type"])['ride_id'].count()
pyber_city_rides=pyber_city_rides.sort_values(ascending=False)
# Build Pie Chart
type_city = pyber_city_rides.index
colors=["#FA8072","skyblue","gold"]
explode=[0.1,0,0]
plt.pie(pyber_city_rides,explode=explode,labels=type_city,colors=colors,autopct="%1.1f%%",shadow=True,startangle=270)
plt.title('% of Total Rides by City Type')
plt.show()
# Save Figure
plt.savefig("Total Fare Rides By City.png")

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Type Percents
pyber_city_drivers=city.groupby(["type"])['driver_count'].sum()
pyber_city_drivers=pyber_city_drivers.sort_values(ascending=False)
# Build Pie Chart
type_city = pyber_city_drivers.index
colors=["#FA8072","skyblue","gold"]
explode=[0.1,0,0]
plt.pie(pyber_city_drivers,explode=explode,labels=type_city,colors=colors,autopct="%1.1f%%",shadow=True,startangle=270)
plt.title('% of Total Drivers by City Type')
plt.show()
# Save Figure
plt.savefig("Total Drivers By City.png")

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
